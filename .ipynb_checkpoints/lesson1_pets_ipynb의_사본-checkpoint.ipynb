# %% [markdown]
# <a href="https://colab.research.google.com/github/yj0905/2020/blob/master/lesson1_pets_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > ## 수고하셨습니다. 이번 exercise를 정말 열심히 공부하신 것 같습니다. 궁금해 하시는 부분에 제가 아는 한 설명을 덧붙였습니다.
# > ## error rate를 줄이려 한 시도도 좋았습니다.

# %% [markdown]
# # Lesson 1 - What's your pet

# %% [markdown]
# Welcome to lesson 1! For those of you who are using a Jupyter Notebook for the first time, you can learn about this useful tool in a tutorial we prepared specially for you; click `File`->`Open` now and click `00_notebook_tutorial.ipynb`.
#
# In this lesson we will build our first image classifier from scratch, and see if we can achieve world-class results. Let's dive in!
#
# Every notebook starts with the following three lines; they ensure that any edits to libraries you make are reloaded here automatically, and also that any charts or images displayed are shown in this notebook.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline   #시작할 때 실행

# %% [markdown]
# We import all the necessary packages. We are going to work with the [fastai V1 library](http://www.fast.ai/2018/10/02/fastai-ai/) which sits on top of [Pytorch 1.0](https://hackernoon.com/pytorch-1-0-468332ba5163). The fastai library provides many useful functions that enable us to quickly and easily build neural networks and train our models.

# %%
from fastai.vision import *
from fastai.metrics import error_rate  #fastai library

# %% [markdown]
# If you're using a computer with an unusually small GPU, you may get an out of memory error when running this notebook. If this happens, click Kernel->Restart, uncomment the 2nd line below to use a smaller *batch size* (you'll learn all about what this means during the course), and try again.

# %%
bs = 64
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# ## Looking at the data

# %% [markdown]
# We are going to use the [Oxford-IIIT Pet Dataset](http://www.robots.ox.ac.uk/~vgg/data/pets/) by [O. M. Parkhi et al., 2012](http://www.robots.ox.ac.uk/~vgg/publications/2012/parkhi12a/parkhi12a.pdf) which features 12 cat breeds and 25 dogs breeds. Our model will need to learn to differentiate between these 37 distinct categories. According to their paper, the best accuracy they could get in 2012 was 59.21%, using a complex model that was specific to pet detection, with separate "Image", "Head", and "Body" models for the pet photos. Let's see how accurate we can be using deep learning!
#
# We are going to use the `untar_data` function to which we must pass a URL as an argument and which will download and extract the data.

# %%
help(untar_data)  #untar_data 도움말?
# Out:
# Help on function untar_data in module fastai.datasets:
#
# untar_data(url:str, fname:Union[pathlib.Path, str]=None, dest:Union[pathlib.Path, str]=None, data=True, force_download=False) -> pathlib.Path
#     Download `url` to `fname` if `dest` doesn't exist, and un-tgz to folder `dest`.

# %%
path = untar_data(URLs.PETS); path  #url에서 다운받고 경로 값 반환
# Out:
# ...
# PosixPath('/root/.fastai/data/oxford-iiit-pet')

# %%
path.ls() #디렉토리 나열
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/annotations'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images')]

# %%
path_anno = path/'annotations'
path_img = path/'images'     #pathlib

# %% [markdown]
# The first thing we do when we approach a problem is to take a look at the data. We _always_ need to understand very well what the problem is and what the data looks like before we can figure out how to solve it. Taking a look at the data means understanding how the data directories are structured, what the labels are and what some sample images look like.
#
# The main difference between the handling of image classification datasets is the way labels are stored. In this particular dataset, labels are stored in the filenames themselves. We will need to extract them to be able to classify the images into the correct categories. Fortunately, the fastai library has a handy function made exactly for this, `ImageDataBunch.from_name_re` gets the labels from the filenames using a [regular expression](https://docs.python.org/3.6/library/re.html).

# %%
fnames = get_image_files(path_img)
fnames[:5]   #파일에서 label 추출
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_112.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/keeshond_61.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Siamese_77.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/leonberger_17.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_193.jpg')]

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'   #the regular expression(정규 표현식)

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224, bs=bs).normalize(imagenet_stats) #데이터 변환. 정규화

# %%
data.show_batch(rows=3, figsize=(7,6))  #데이터 미리보기

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']
# (37, 37)

# %% [markdown]
# ## Training: resnet34

# %% [markdown]
# Now we will start training our model. We will use a [convolutional neural network](http://cs231n.github.io/convolutional-networks/) backbone and a fully connected head with a single hidden layer as a classifier. Don't know what these things mean? Not to worry, we will dive deeper in the coming lessons. For the moment you need to know that we are building a model which will take images as input and will output the predicted probability for each of the categories (in this case, it will have 37 outputs).
#
# We will train for 4 epochs (4 cycles through all our data).

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)  #사전 훈련된 가중치 다운 / resnet 34: 모델 구조의 레이어 수
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
learn.fit_one_cycle(4)  #데이터 세트 4번 통과. 오류율 감소. 너무 반복할 시 과적합(overfitting) 일어날 수 있다.
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.397756</td>
#       <td>0.258394</td>
#       <td>0.089310</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.629189</td>
#       <td>0.257542</td>
#       <td>0.091340</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.374911</td>
#       <td>0.228750</td>
#       <td>0.073072</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.274389</td>
#       <td>0.206805</td>
#       <td>0.064953</td>
#       <td>01:24</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %% [markdown]
# ## Results

# %% [markdown]
# Let's see what results we have got.
#
# We will first see which were the categories that the model most confused with one another. We will try to see if what the model predicted was reasonable or not. In this case the mistakes look reasonable (none of the mistakes seems obviously naive). This is an indicator that our classifier is working correctly.
#
# Furthermore, when we plot the confusion matrix, we can see that the distribution is heavily skewed: the model makes the same mistakes over and over again but it rarely confuses other categories. This suggests that it just finds it difficult to distinguish some specific categories between each other; this is normal behaviour.

# %%
interp = ClassificationInterpretation.from_learner(learn)   #Classific~: confusing matrix 생성

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))  #최고 손실(top loss)

# %%
doc(interp.plot_top_losses)  #설명
# Out:
# <h4 id="_cl_int_plot_top_losses" class="doc_header"><code>_cl_int_plot_top_losses</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/learner.py#L163" class="source_link" style="float:right">[source]</a><a class="source_link" data-toggle="collapse" data-target="#_cl_int_plot_top_losses-pytest" style="float:right; padding-right:10px">[test]</a></h4><blockquote><p><code>_cl_int_plot_top_losses</code>(<strong><code>k</code></strong>, <strong><code>largest</code></strong>=<strong><em><code>True</code></em></strong>, <strong><code>figsize</code></strong>=<strong><em><code>(12, 12)</code></em></strong>, <strong><code>heatmap</code></strong>:<code>bool</code>=<strong><em><code>False</code></em></strong>, <strong><code>heatmap_thresh</code></strong>:<code>int</code>=<strong><em><code>16</code></em></strong>, <strong><code>alpha</code></strong>:<code>float</code>=<strong><em><code>0.6</code></em></strong>, <strong><code>cmap</code></strong>:<code>str</code>=<strong><em><
# ...

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60) #confusion matrix(컨퓨전 행렬)/ 정확: 높은 숫자,진한 색깔/부정확: 낮은 숫자

# %%
interp.most_confused(min_val=2)  #가장 많이 틀린 조합
# Out:
# [('Ragdoll', 'Birman', 5),
#  ('Bengal', 'Abyssinian', 4),
#  ('Siamese', 'Birman', 4),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 4),
#  ('yorkshire_terrier', 'havanese', 4),
#  ('Bengal', 'Egyptian_Mau', 3),
#  ('British_Shorthair', 'Russian_Blue', 3),
#  ('Egyptian_Mau', 'Bengal', 3),
#  ('Sphynx', 'chihuahua', 3),
#  ('basset_hound', 'beagle', 3),
#  ('staffordshire_bull_terrier', 'american_bulldog', 3),
#  ('Birman', 'Siamese', 2),
#  ('British_Shorthair', 'Bombay', 2),
#  ('Egyptian_Mau', 'Abyssinian', 2),
#  ('Maine_Coon', 'Ragdoll', 2),
#  ('american_pit_bull_terrier', 'american_bulldog', 2),
#  ('beagle', 'basset_hound', 2),
#  ('chihuahua', 'miniature_pinscher', 2),
#  ('miniature_pinscher', 'staffordshire_bull_terrier', 2)]

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.
#
# [link](https://forums.fast.ai/t/why-do-we-need-to-unfreeze-the-learner-everytime-before-retarining-even-if-learn-fit-one-cycle-works-fine-without-learn-unfreeze/41614)<-unfreeze를 한 후 fit_one_cycle(1)하는 이유?

# %%
learn.unfreeze() #모든 모델 훈련 #학습하기 전의 초기상태로 되돌린다? 필요한 이유는?

# %% [markdown]
# > ## 좋은 질문입니다. 이미 link 까지 찾아보셨네요.
# > ## deeplearning은 동영상에서 설명한 것과 같이 layer들이 층층이 쌓여 있어, 매우 단순한 부분부터 학습해, 이를 이용하여 더 고도의 것까지 학습하는 과정을 가집니다.
# > ## link에서 잘 설명했듯이, fast.ai가 제공하는 저희가 사용하는 모델들은 이미 기본적인 layer들을 학습을 완료해 놓은 모델들입니다.(이번 exercise에서는 cnn_learner)
# > ## 이를 가져와 위에서 저희가 불러온 고양이 dataset을 학습하기 위해 fit_one_cycle(4)를 하는 거고요. 그리고 그 학습된 모델을 'stage-1'에 저장합니다.
# > ## 하지만, 위 밑의 부분들은 저희가 새로이 처음부터 training(학습)을 시키는 부분이기에, 이미 학습된 내용들을 없애기 위해 unfreeze를 하는 것입니다.
# > ## fit_one_cycle을 하는 이유는 다시 학습하기 위해서입니다!!

# %%
learn.fit_one_cycle(1)  #오류율 증가함. 0.065->0.128
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.730490</td>
#       <td>0.376520</td>
#       <td>0.127876</td>
#       <td>01:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (5912 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# staffordshire_bull_terrier,keeshond,Siamese,havanese,wheaten_terrier
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Valid: LabelList (1478 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# boxer,British_Shorthair,english_cocker_spaniel,Russian_Blue,keeshond
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
# ...

# %%
learn.lr_find() #learning rate finder(학습률 찾기)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.recorder.plot() #lr finder 결과. 10^(-3) 이후 learning rate가 높아지면 loss 증가.

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4)) #처음은 10^(-6)으로 시작해서 나중에는 10^(-4)로 속도 올림. 오류율 아까보다 더욱 감소.
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.263215</td>
#       <td>0.199941</td>
#       <td>0.064276</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.233288</td>
#       <td>0.204251</td>
#       <td>0.064276</td>
#       <td>01:26</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# That's a pretty accurate model!

# %% [markdown]
# ## Training: resnet50

# %% [markdown]
# Now we will train in the same way as before but with one caveat: instead of using resnet34 as our backbone we will use resnet50 (resnet34 is a 34 layer residual network while resnet50 has 50 layers. It will be explained later in the course and you can learn the details in the [resnet paper](https://arxiv.org/pdf/1512.03385.pdf)).
#
# Basically, resnet50 usually performs better because it is a deeper network with more parameters. Let's see if we can achieve a higher performance here. To help it along, let's us use larger images too, since that way the network can see more detail. We reduce the batch size a bit since otherwise this larger network will require more GPU memory.

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=299, bs=bs//2).normalize(imagenet_stats) #레이어 수가 증가해 메모리가 부족할 수 있어 batch size를 32로.
#데이터 정규화.

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate) #resnet 50 사용.
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# ...

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.fit_one_cycle(8) #오류율 0.047로 감소.
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.703436</td>
#       <td>0.273143</td>
#       <td>0.083221</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.509241</td>
#       <td>0.278280</td>
#       <td>0.100135</td>
#       <td>02:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.428579</td>
#       <td>0.245518</td>
#       <td>0.076455</td>
#       <td>02:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.345028</td>
#       <td>0.230377</td>
#       <td>0.068336</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.263763</td>
#       <td>0.199464</td>
#       <td>0.057510</td>
#       <td>02:18</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1-50')

# %% [markdown]
# It's astonishing that it's possible to recognize pet breeds so accurately! Let's see if full fine-tuning helps:

# %%
learn.unfreeze()
learn.fit_one_cycle(3, max_lr=slice(1e-6,1e-4)) #learning rate 변화시키면 error rate 더 증가.
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.109145</td>
#       <td>0.160719</td>
#       <td>0.048714</td>
#       <td>02:39</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.091668</td>
#       <td>0.155241</td>
#       <td>0.050068</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.083997</td>
#       <td>0.154977</td>
#       <td>0.050744</td>
#       <td>02:39</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# If it doesn't, you can always go back to your previous model.

# %%
learn.load('stage-1-50'); #이전모델 불러오기

# %%
interp = ClassificationInterpretation.from_learner(learn) #결과 해석

# %%
interp.most_confused(min_val=2)  #most_confused로 혼란스러워하는 종류 찾음.
# Out:
# [('Ragdoll', 'Birman', 5),
#  ('miniature_pinscher', 'chihuahua', 5),
#  ('Bengal', 'Egyptian_Mau', 4),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 4),
#  ('boxer', 'american_bulldog', 4),
#  ('Birman', 'Ragdoll', 3),
#  ('yorkshire_terrier', 'havanese', 3),
#  ('British_Shorthair', 'Russian_Blue', 2),
#  ('Egyptian_Mau', 'Bengal', 2),
#  ('Persian', 'Ragdoll', 2),
#  ('Ragdoll', 'Persian', 2),
#  ('miniature_pinscher', 'american_pit_bull_terrier', 2),
#  ('staffordshire_bull_terrier', 'american_bulldog', 2)]

# %% [markdown]
# ## Other data formats

# %%
path = untar_data(URLs.MNIST_SAMPLE); path #손으로 그린 숫자(MINST)샘플
# Out:
# ...
# PosixPath('/root/.fastai/data/mnist_sample')

# %%
tfms = get_transforms(do_flip=False)
data = ImageDataBunch.from_folder(path, ds_tfms=tfms, size=26) #ImageDataBunch 생성.

# %%
data.show_batch(rows=3, figsize=(5,5)) #labels 생성.

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy)
learn.fit(2)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
# ...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.199931</td>
#       <td>0.089089</td>
#       <td>0.971050</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.124207</td>
#       <td>0.058373</td>
#       <td>0.980864</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = pd.read_csv(path/'labels.csv')
df.head() #csv 파일
# Out:
#                 name  label
# 0   train/3/7463.png      0
# 1  train/3/21102.png      0
# 2  train/3/31559.png      0
# 3  train/3/46882.png      0
# 4  train/3/26209.png      0

# %%
data = ImageDataBunch.from_csv(path, ds_tfms=tfms, size=28) #csv파일이 label됨.

# %%
data.show_batch(rows=3, figsize=(5,5))
data.classes
# Out:
# [0, 1]

# %%
data = ImageDataBunch.from_df(path, df, ds_tfms=tfms, size=24)
data.classes #label이 왜 0,1이 되는가?
# Out:
# [0, 1]

# %% [markdown]
# > # 이전 예시는 3,7로 labelling이 되어있던 거라면,
# > # 이번 csv 예시는 3이면 0, 7이면 1로 labelling 되어 있었기 때문입니다.

# %%
fn_paths = [path/name for name in df['name']]; fn_paths[:2] #path
# Out:
# [PosixPath('/root/.fastai/data/mnist_sample/train/3/7463.png'),
#  PosixPath('/root/.fastai/data/mnist_sample/train/3/21102.png')]

# %%
pat = r"/(\d)/\d+\.png$"
data = ImageDataBunch.from_name_re(path, fn_paths, pat=pat, ds_tfms=tfms, size=24)
data.classes  #정규 표현식으로 label 추출.
# Out:
# ['3', '7']

# %%
data = ImageDataBunch.from_name_func(path, fn_paths, ds_tfms=tfms, size=24,
        label_func = lambda x: '3' if '/3/' in str(x) else '7')
data.classes  #복잡한 파일 이름 또는 경로에서 label 추출하는 임의의 함수:from_name_func
# Out:
# ['3', '7']

# %%
labels = [('3' if '/3/' in str(x) else '7') for x in fn_paths]
labels[:5] #label 배열 만들기
# Out:
# ['3', '3', '3', '3', '3']

# %%
data = ImageDataBunch.from_lists(path, fn_paths, labels=labels, ds_tfms=tfms, size=24)
data.classes #label 배열을 목록으로.
# Out:
# ['3', '7']
